# %%
# No warnings
import warnings
warnings.filterwarnings('ignore') # Filter out warnings

# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### Load Data

# %%
#Columns based on documentation
##Note: I added 3 dummy colunmns because the number of columns dont match with dataset

colnames=['ID', 'Birth Year', 'Gender Flag', 'Skillset1', 'Skillset1 Weight', 'Skillset2', 'Skillset2 Weight', 'City of profile','Country of profile','Education','Elite Institution', 'Start Date', 'StartFlag','End Date', 'EndFlag', 'CurrentEmployFlag','Length','Role','Dept','Company','Company_Norm','Ticker','Exchange','PublicFlag','Location','Industry','EducationFlag','DegreeType','EliteFlag','Dummy1','Dummy2','Dummy3'] 
len(colnames)
# Out:
# 32

# %%
#Read the full romanians.csv
#Warning: May take some time
full_df = pd.read_csv('C:/AI4Good/romanians.csv',sep="\t")

# %%
full_df.head()
# Out:
#    0ec6dbef99b11f7ec15f9f6f18ada59f  1993  0                   -1       0.1  \
# 0  0ec6dbef99b11f7ec15f9f6f18ada59f  1993  0                   -1  0.000000
# 1  1c711330177d7e04b0b42b11a8e4650c  1989  1  Banking and Finance  0.996699
# 2  1c711330177d7e04b0b42b11a8e4650c  1989  1  Banking and Finance  0.996699
# 3  1c711330177d7e04b0b42b11a8e4650c  1989  1  Banking and Finance  0.996699
# 4  1c711330177d7e04b0b42b11a8e4650c  1989  1  Banking and Finance  0.996699
#
#                       -1.1       0.2 Unnamed: 7  Romania  0.3  False  \
# 0                       -1  0.000000        NaN  Romania    0  False
# 1  Accounting and Auditing  0.001583        NaN  Romania    0  False
# 2  Accounting and Auditing  0.001583        NaN  Romania    0  False
# 3  Accounting and Auditing  0.001583        NaN  Romania    0  False
# 4  Accounting and Auditing  0.001583        NaN  Romania    0  False
#
#    2011-01-01  False.1 2011-01-01.1  False.2  False.3     0.4  \
# ...

# %%
#no. of rows
full_df.shape[0]
# Out:
# 5482351

# %%
#no. of columns
full_df.shape[1]
# Out:
# 32

# %%
#Put the column names
full_df.columns=colnames

# %%
full_df.head()
# Out:
#                                  ID Birth Year  Gender Flag  \
# 0  0ec6dbef99b11f7ec15f9f6f18ada59f       1993            0
# 1  1c711330177d7e04b0b42b11a8e4650c       1989            1
# 2  1c711330177d7e04b0b42b11a8e4650c       1989            1
# 3  1c711330177d7e04b0b42b11a8e4650c       1989            1
# 4  1c711330177d7e04b0b42b11a8e4650c       1989            1
#
#              Skillset1  Skillset1 Weight                Skillset2  \
# 0                   -1          0.000000                       -1
# 1  Banking and Finance          0.996699  Accounting and Auditing
# 2  Banking and Finance          0.996699  Accounting and Auditing
# 3  Banking and Finance          0.996699  Accounting and Auditing
# 4  Banking and Finance          0.996699  Accounting and Auditing
#
#    Skillset2 Weight City of profile Country of profile  Education  \
# 0          0.000000             NaN            Romania          0
# 1          0.001583             NaN            Romania          0
# ...

# %%
#Extracting just a subset to take a look
full_df.iloc[1:20, :]
# Out:
#                                   ID Birth Year  Gender Flag  \
# 1   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 2   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 3   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 4   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 5   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 6   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 7   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 8   db24808a6a05b9908c7af8d21cd50c35       1995            1
# 9   db24808a6a05b9908c7af8d21cd50c35       1995            1
# 10  db24808a6a05b9908c7af8d21cd50c35       1995            1
# 11  2340e3bdc451a860c3973d65359b0ed5       1977            2
# 12  2340e3bdc451a860c3973d65359b0ed5       1977            2
# 13  2340e3bdc451a860c3973d65359b0ed5       1977            2
# 14  ab60dafc0eca62ac6f3a17747f1b0a94       2000            2
# ...

# %%
full_df.set_index('ID')
# Out:
#                                  Birth Year  Gender Flag  \
# ID
# 0ec6dbef99b11f7ec15f9f6f18ada59f       1993            0
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# 1c711330177d7e04b0b42b11a8e4650c       1989            1
# db24808a6a05b9908c7af8d21cd50c35       1995            1
# db24808a6a05b9908c7af8d21cd50c35       1995            1
# db24808a6a05b9908c7af8d21cd50c35       1995            1
# 2340e3bdc451a860c3973d65359b0ed5       1977            2
# 2340e3bdc451a860c3973d65359b0ed5       1977            2
# 2340e3bdc451a860c3973d65359b0ed5       1977            2
# ab60dafc0eca62ac6f3a17747f1b0a94       2000            2
# ...

# %%
full_df[full_df['Dummy1'].notnull()][0:5]
# Out:
#                                      ID Birth Year  Gender Flag  \
# 17834  b366a80b1aa9f6c75a564ff3415def8d       1990            0
# 19847  4f303919ccda37e0329f980e41721dce       1981            1
# 29765  b73393e8e27932c91e7266ff47e6ffcc       1977            2
# 30459  fb78f4860ad580863bb5ee287b54b385       1983            1
# 30462  fb78f4860ad580863bb5ee287b54b385       1983            1
#
#              Skillset1  Skillset1 Weight                     Skillset2  \
# 17834  Web Development          0.768134  Technical Product Management
# 19847               -1          0.000000                            -1
# 29765               -1          0.000000                            -1
# 30459       Recruiting          0.287325      Human Resources (Senior)
# 30462       Recruiting          0.287325      Human Resources (Senior)
#
#        Skillset2 Weight City of profile Country of profile  Education  \
# 17834          0.082479             NaN            Ireland          4
# ...

# %%
full_df[full_df['Dummy3'].notnull()][0:5]
# Out:
#                                   ID Birth Year  Gender Flag  \
# 5   1c711330177d7e04b0b42b11a8e4650c       1989            1
# 20  7bb878706a05ff7d8e10c6bc3ce46660       1982            2
# 23  f4f393a13194eb3b71a9bb59affcefa6       1980            1
# 28  884e2af323c92162bdba9f7a630dabad       1999            0
# 35  33b519f48a5532c2978cc4f220490ccd       1975            1
#
#               Skillset1  Skillset1 Weight                Skillset2  \
# 5   Banking and Finance          0.996699  Accounting and Auditing
# 20                   -1          0.000000                       -1
# 23     Sales Management          0.243114                    Sales
# 28                   -1          0.000000                       -1
# 35     Sales Management          0.404712           Administration
#
#     Skillset2 Weight City of profile Country of profile  Education  \
# 5           0.001583             NaN            Romania          0
# ...

# %%
print(pd.unique(full_df['Dummy1']))
# Out:
# [nan 'computer science' 'management' 'sociology' 'economics'
#  'political science,humanities' 'political science' 'history'
#  'mathematics,computer science' 'law' 'music' 'management,economics'
#  'philosophy' 'electrical engineering' 'psychology'
#  'german,philosophy,french' 'french' 'economics,political science'
#  'architecture' 'mathematics' 'management,computer science'
#  'religious studies,music' 'religious studies' 'music,history'
#  'medieval studies,music' 'renaissance studies' 'french,history'
#  'religious studies,french' 'sociology,american studies'
#  'anthropology,sociology,american studies' 'linguistics' 'physics'
#  'law,french' 'surgery' 'german,french' 'economics,physics'
#  'sociology,psychology' 'nursing' 'chemistry,physics'
#  'mathematics,physics' 'philosophy,architecture' 'philosophy,physics'
#  'physics,history' 'humanities' 'classics' 'philosophy,classics'
#  'pharmacology' 'philosophy,history' 'management,philosophy,history'
# ...

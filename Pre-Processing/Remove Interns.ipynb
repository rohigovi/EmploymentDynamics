# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("/Users/wl/Desktop/UCB/Data X/Project/Datasets/common_companies.csv",index_col=0,encoding = "latin1")

# %%
len(df['Role'])
# Out:
# 8040

# %%
df.index = np.arange(0, len(df))

# %%
df.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 1  1fe596b8-87d0-3118-ab5e-375485b477e9       1984            0
# 2  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 3  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 4  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
#
#                    Skillset1  Skillset1 Weight             Skillset2  \
# 0            Web Development          0.919146  Software Engineering
# 1  Mobile Telecommunications          0.571192  Business Development
# 2            Human Resources          0.264015       Human Resources
# 3                 Web Design          0.428620     Digital Marketing
# 4       Software Engineering          0.704756       Web Development
#
#    Skillset2 Weight City of profile Country of profile  Education  \
# 0          0.068156     Los Angeles      United States          5
# ...

# %%
df.columns.get_loc('Role')
# Out:
# 17

# %%
df['temp']=1
df.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 1  1fe596b8-87d0-3118-ab5e-375485b477e9       1984            0
# 2  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 3  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 4  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
#
#                    Skillset1  Skillset1 Weight             Skillset2  \
# 0            Web Development          0.919146  Software Engineering
# 1  Mobile Telecommunications          0.571192  Business Development
# 2            Human Resources          0.264015       Human Resources
# 3                 Web Design          0.428620     Digital Marketing
# 4       Software Engineering          0.704756       Web Development
#
#    Skillset2 Weight City of profile Country of profile  Education ...   \
# 0          0.068156     Los Angeles      United States          5 ...
# ...

# %%
import re
for i in range(8040):
    role=df.iloc[i,17]
    x = re.findall(r"\bIntern\b", role)
    if (x):
        df.at[i, 'temp'] = 0
        #print('match')
        #print(i)
        i=i+1
    else:
        #print('no match')
        i=i+1

# %%
df.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 1  1fe596b8-87d0-3118-ab5e-375485b477e9       1984            0
# 2  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 3  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 4  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
#
#                    Skillset1  Skillset1 Weight             Skillset2  \
# 0            Web Development          0.919146  Software Engineering
# 1  Mobile Telecommunications          0.571192  Business Development
# 2            Human Resources          0.264015       Human Resources
# 3                 Web Design          0.428620     Digital Marketing
# 4       Software Engineering          0.704756       Web Development
#
#    Skillset2 Weight City of profile Country of profile  Education ...   \
# 0          0.068156     Los Angeles      United States          5 ...
# ...

# %%
df1 = df.drop(df[df['temp']==0].index)

# %%
df1.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 2  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 3  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 4  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
# 5  f1794807-6618-3fcc-9714-728ff081f4b4       1987            1
#
#               Skillset1  Skillset1 Weight             Skillset2  \
# 0       Web Development          0.919146  Software Engineering
# 2       Human Resources          0.264015       Human Resources
# 3            Web Design          0.428620     Digital Marketing
# 4  Software Engineering          0.704756       Web Development
# 5        Administration          0.461406        Administration
#
#    Skillset2 Weight City of profile Country of profile  Education ...   \
# 0          0.068156     Los Angeles      United States          5 ...
# ...

# %%
df2 = df1.drop('temp',axis=1)

# %%
df2.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 2  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 3  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 4  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
# 5  f1794807-6618-3fcc-9714-728ff081f4b4       1987            1
#
#               Skillset1  Skillset1 Weight             Skillset2  \
# 0       Web Development          0.919146  Software Engineering
# 2       Human Resources          0.264015       Human Resources
# 3            Web Design          0.428620     Digital Marketing
# 4  Software Engineering          0.704756       Web Development
# 5        Administration          0.461406        Administration
#
#    Skillset2 Weight City of profile Country of profile  Education  \
# 0          0.068156     Los Angeles      United States          5
# ...

# %%
len(df2)
# Out:
# 7146

# %%
df_final=df2
df_final.index = np.arange(0, len(df_final))
df_final.head()
# Out:
#                                      ID Birth Year  Gender Flag  \
# 0  808a3ae7-b1ec-31f0-9335-8f49e4e10a40       1988            0
# 1  43d4f687-4de8-39e0-91f4-ed90ba1e2862       1967            2
# 2  6870e27a-1eb0-3be6-8878-43b3adc611cc       1964            0
# 3  8da0eaa5-8d1a-3360-986d-4ab1f5658930       1992            2
# 4  f1794807-6618-3fcc-9714-728ff081f4b4       1987            1
#
#               Skillset1  Skillset1 Weight             Skillset2  \
# 0       Web Development          0.919146  Software Engineering
# 1       Human Resources          0.264015       Human Resources
# 2            Web Design          0.428620     Digital Marketing
# 3  Software Engineering          0.704756       Web Development
# 4        Administration          0.461406        Administration
#
#    Skillset2 Weight City of profile Country of profile  Education  \
# 0          0.068156     Los Angeles      United States          5
# ...

# %%
len(df_final)
# Out:
# 7146

# %%
df_final.to_csv('Interns Removed.csv', sep='\t', encoding='utf-8')
